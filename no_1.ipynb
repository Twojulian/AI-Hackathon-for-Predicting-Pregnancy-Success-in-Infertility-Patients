# %%
import pandas as pd

df = pd.read_csv("/Users/admin/Desktop/infertility/open (1)/train.csv")

# # 전체 컬럼 각각의 값별 카운트
# for col in df.columns:
#     print(f"\n[{col}]")
#     print(df[col].value_counts())  양이 많아  잘려서 나옴.

# %%
print(df['시술 시기 코드'].value_counts(dropna=False))
# Out:
# 시술 시기 코드
# TRDQAZ    38969
# TRCMWS    38090
# TRYBLT    36713
# TRVNRY    36173
# TRJXFG    36031
# TRZKPL    35544
# TRXQMD    34831
# Name: count, dtype: int64

# %%
print(df['시술 당시 나이'].value_counts(dropna=False))
# Out:
# 시술 당시 나이
# 만18-34세    102476
# 만35-37세     57780
# 만38-39세     39247
# 만40-42세     37348
# 만43-44세     12253
# 만45-50세      6918
# 알 수 없음        329
# Name: count, dtype: int64

# %%
print(df['임신 시도 또는 마지막 임신 경과 연수'].value_counts(dropna=False))
# Out:
# 임신 시도 또는 마지막 임신 경과 연수
# NaN     246981
# 7.0       1214
# 8.0       1176
# 9.0       1023
# 6.0        991
# 10.0       947
# 11.0       701
# 5.0        692
# 12.0       510
# 13.0       481
# 14.0       331
# 4.0        305
# 15.0       254
# 16.0       202
# 17.0       140
# 18.0       106
# 3.0         89
# 19.0        86
# 20.0        83
# 2.0         21
# 0.0         12
# 1.0          6
# Name: count, dtype: int64

# %%
print(df['시술 유형'].value_counts(dropna=False))
# Out:
# 시술 유형
# IVF    250060
# DI       6291
# Name: count, dtype: int64

# %%
print(df['특정 시술 유형'].value_counts(dropna=False))
# Out:
# 특정 시술 유형
# ICSI                                   122368
# IVF                                     91755
# Unknown                                 26939
# IUI                                      6100
# ICSI:ICSI                                2314
# ICSI / BLASTOCYST                        1609
# IVF / BLASTOCYST                         1248
# IVF:IVF                                  1146
# ICSI:IVF                                  873
# ICSI / AH                                 769
# IVF:ICSI                                  392
# IVF / AH                                  319
# ICSI:Unknown                              207
# IVF:Unknown                               100
# ICI                                        96
# Generic DI                                 71
# IVI                                        23
# ICSI / BLASTOCYST:IVF / BLASTOCYST          6
# ICSI / BLASTOCYST :IVF / BLASTOCYST         4
# FER                                         3
# ...

# %%
print(df['배란 자극 여부'].value_counts(dropna=False))
# Out:
# 배란 자극 여부
# 1    197720
# 0     58631
# Name: count, dtype: int64

# %%
print(df['배란 유도 유형'].value_counts(dropna=False))
# Out:
# 배란 유도 유형
# 기록되지 않은 시행      194432
# 알 수 없음           61917
# 세트로타이드 (억제제)         1
# 생식선 자극 호르몬           1
# Name: count, dtype: int64

# %%
print(df['단일 배아 이식 여부'].value_counts(dropna=False))
# Out:
# 단일 배아 이식 여부
# 0.0    191677
# 1.0     58383
# NaN      6291
# Name: count, dtype: int64

# %%
print(df['착상 전 유전 검사 사용 여부'].value_counts(dropna=False))
# Out:
# 착상 전 유전 검사 사용 여부
# NaN    253633
# 1.0      2718
# Name: count, dtype: int64

# %%
print(df['착상 전 유전 진단 사용 여부'].value_counts(dropna=False))
# Out:
# 착상 전 유전 진단 사용 여부
# 0.0    246864
# NaN      6291
# 1.0      3196
# Name: count, dtype: int64

# %%
print(df['남성 주 불임 원인'].value_counts(dropna=False))
# Out:
# 남성 주 불임 원인
# 0    249041
# 1      7310
# Name: count, dtype: int64

# %%
print(df['남성 부 불임 원인'].value_counts(dropna=False))
# Out:
# 남성 부 불임 원인
# 0    252989
# 1      3362
# Name: count, dtype: int64

# %%
print(df['여성 주 불임 원인'].value_counts(dropna=False))
# Out:
# 여성 주 불임 원인
# 0    248475
# 1      7876
# Name: count, dtype: int64

# %%
print(df['여성 부 불임 원인'].value_counts(dropna=False))
# Out:
# 여성 부 불임 원인
# 0    253164
# 1      3187
# Name: count, dtype: int64

# %%
print(df['임신 성공 여부'].value_counts(dropna=False))
# Out:
# 임신 성공 여부
# 0    190123
# 1     66228
# Name: count, dtype: int64
